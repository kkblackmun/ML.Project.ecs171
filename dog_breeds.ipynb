# %% [markdown]
# # 70 Dog Breeds Neural Net

# %% [markdown]
# Data Exploration Stage:

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the train test and valid data sets

# %%
# # this section only for using Colab
# # this method should work, haven't tested

# from google.colab import drive

# # this is my directory path name, you can make a path exact as this path,
# # or modify the path below to fit your path
# # when you open Google Drive, the main page is on "My Drive" level
# foldername = "/content/gdrive/My Drive/DropBox/GroupProject/ML.Project.ecs171-main"

# drive.mount(foldername)

# %%
train =  pd.read_csv('dogs.csv')
test =  pd.read_csv('dogs.csv')
valid =  pd.read_csv('dogs.csv')
data_all = pd.read_csv('dogs.csv')

# %% [markdown]
# Modifying so they have the right train test and valid values.

# %%
train = train[train.dataset == 'train']
test = test[test.dataset == 'test']
valid = valid[valid.dataset == 'valid']

# %%
display(valid)
# Out:
#                 filepaths  labels dataset
# 8646  valid/Afghan/01.jpg  Afghan   valid
# 8647  valid/Afghan/02.jpg  Afghan   valid
# 8648  valid/Afghan/03.jpg  Afghan   valid
# 8649  valid/Afghan/04.jpg  Afghan   valid
# 8650  valid/Afghan/05.jpg  Afghan   valid
# ...                   ...     ...     ...
# 9341  valid/Yorkie/06.jpg  Yorkie   valid
# 9342  valid/Yorkie/07.jpg  Yorkie   valid
# 9343  valid/Yorkie/08.jpg  Yorkie   valid
# 9344  valid/Yorkie/09.jpg  Yorkie   valid
# 9345  valid/Yorkie/10.jpg  Yorkie   valid
#
# [700 rows x 3 columns]

# %% [markdown]
# Showing an example image.
# All images are in the resolution of 224x224 and do not require any resizing or cropping or normalization by us.<br>
# Number of Images: 93406<br>
# Number of Training Images: 7946<br>
# Number of Test Images: 700<br>
# Number of Valid Images: 700<br>

# %%
from IPython.display import Image
imgname = test.filepaths[7946]
display(imgname)
Image(filename= imgname)
# Out:
# 'test/Afghan/01.jpg'

# %% [markdown]
# Showing all the unique types of breeds in the data set. Which we will use to form our classes<br>
# We noticed here that there was a typo in the dog breed "American Spaniel" that divided it into two seperate classes. We fixed this by using the replace function and now it is all uniform.

# %%
data_all['labels'] = data_all['labels'].replace(['American  Spaniel'], 'American Spaniel')
breeds = data_all['labels'].unique()
display(breeds)
# Out:
# array(['Afghan', 'African Wild Dog', 'Airedale', 'American Hairless',
#        'American Spaniel', 'Basenji', 'Basset', 'Beagle',
#        'Bearded Collie', 'Bermaise', 'Bichon Frise', 'Blenheim',
#        'Bloodhound', 'Bluetick', 'Border Collie', 'Borzoi',
#        'Boston Terrier', 'Boxer', 'Bull Mastiff', 'Bull Terrier',
#        'Bulldog', 'Cairn', 'Chihuahua', 'Chinese Crested', 'Chow',
#        'Clumber', 'Cockapoo', 'Cocker', 'Collie', 'Corgi', 'Coyote',
#        'Dalmation', 'Dhole', 'Dingo', 'Doberman', 'Elk Hound',
#        'French Bulldog', 'German Sheperd', 'Golden Retriever',
#        'Great Dane', 'Great Perenees', 'Greyhound', 'Groenendael',
#        'Irish Spaniel', 'Irish Wolfhound', 'Japanese Spaniel', 'Komondor',
#        'Labradoodle', 'Labrador', 'Lhasa', 'Malinois', 'Maltese',
#        'Mex Hairless', 'Newfoundland', 'Pekinese', 'Pit Bull',
#        'Pomeranian', 'Poodle', 'Pug', 'Rhodesian', 'Rottweiler',
#        'Saint Bernard', 'Schnauzer', 'Scotch Terrier', 'Shar_Pei',
#        'Shiba Inu', 'Shih-Tzu', 'Siberian Husky', 'Vizsla', 'Yorkie'],
#       dtype=object)

# %%
num_breeds = []
for name in breeds:
    num_breeds.append(len(data_all[data_all.labels == name]))

# %%
sns.set(rc={'figure.figsize':(13,5)})
ax = sns.scatterplot(x = breeds, y = num_breeds)
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# **NN**

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import MaxPooling2D
from keras.layers import Rescaling
from keras.preprocessing.image import ImageDataGenerator

# %%
bSize = 50
lRate = 0.01
Epochs = 30

# %%
Classes = []
for i in breeds:
    Classes.append(i)

# %%
# reference for this ImageDataGenerator image labeling and feeding method:
# https://towardsdatascience.com/a-single-function-to-streamline-image-classification-with-keras-bd04f5cfe6df
# it is a built in function in Keras
train_Gen = ImageDataGenerator(rescale = 1. / 255)
train_genX = train_Gen.flow_from_directory(
    'train',
    target_size = (224, 224),
    batch_size = bSize,
    classes = Classes,
    class_mode = 'categorical'
)
# Out:
# Found 7946 images belonging to 70 classes.

# %%
test_Gen = ImageDataGenerator(rescale = 1. / 255)
test_genX = test_Gen.flow_from_directory(
    'test',
    target_size = (224, 224),
    batch_size = bSize,
    classes = Classes,
    class_mode = 'categorical'
)
# Out:
# Found 700 images belonging to 70 classes.

# %%
val_Gen = ImageDataGenerator(rescale = 1. / 255)
val_genX = val_Gen.flow_from_directory(
    'valid',
    target_size = (224, 224),
    batch_size = bSize,
    classes = Classes,
    class_mode = 'categorical'
)
# Out:
# Found 690 images belonging to 70 classes.

# %%
cnnModel = Sequential()

cnnModel.add(Rescaling(1. / 1, input_shape = (224, 224, 3)))
cnnModel.add(Conv2D(64, 5, padding = 'same', activation = 'relu'))
cnnModel.add(MaxPooling2D((3, 3)))
cnnModel.add(Conv2D(128, 5, padding = 'same', activation = 'relu'))
cnnModel.add(MaxPooling2D((3, 3)))
cnnModel.add(Conv2D(256, 5, padding = 'same', activation = 'relu'))
cnnModel.add(MaxPooling2D((3, 3)))
#cnnModel.add(Conv2D(256, 5, padding = 'same', activation = 'relu'))
#cnnModel.add(MaxPooling2D((3, 3)))
cnnModel.add(Flatten())

cnnModel.add(Dense(256, activation='relu'))
cnnModel.add(Dense(128, activation='relu'))
cnnModel.add(Dense(70, activation='softmax'))

# %%
# cnnModel = Sequential()

# # cnnModel.add(Rescaling(1. / 1, input_shape = (224, 224, 3)))
# cnnModel.add(Conv2D(64, 5, padding = 'same', activation = 'relu'))
# cnnModel.add(MaxPooling2D((3, 3)))
# cnnModel.add(Conv2D(128, 5, padding = 'same', activation = 'relu'))
# cnnModel.add(MaxPooling2D((3, 3)))
# #cnnModel.add(Conv2D(256, 5, padding = 'same', activation = 'relu'))
# #cnnModel.add(MaxPooling2D((3, 3)))
# cnnModel.add(Flatten())

# #cnnModel.add(Dense(256, activation='relu'))
# cnnModel.add(Dense(128, activation='relu'))
# cnnModel.add(Dense(70, activation='softmax'))

# %%
# cnnModel = Sequential([
#     layers.Rescaling(1. / 255, input_shape = (224, 224, 3)),
#     layers.Conv2D(64, 3, padding = 'same', activation = 'relu'),
#     layers.MaxPooling2D(),
#     layers.Conv2D(128, 3, padding = 'same', activation = 'relu'),
#     layers.MaxPooling2D(),
#     layers.Conv2D(256, 3, padding = 'same', activation = 'relu'),
#     layers.MaxPooling2D(),

#     layers.Flatten(),

#     layers.Dense(256, activation = 'relu'),
#     layers.Dense(128, activation = 'relu'),
#     layers.Dense(70, activation = 'relu'),
# ])

# %%
optim = keras.optimizers.SGD(learning_rate = lRate)

#cnnModel.compile(optimizer = optim, loss = 'binary_crossentropy', metrics = ['accuracy'])
cnnModel.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
history = cnnModel.fit(
    train_genX,
    validation_data = val_genX,
    epochs = Epochs
)
# Out:
# Epoch 1/30
# 159/159 [==============================] - 86s 532ms/step - loss: 0.0855 - accuracy: 0.0223 - val_loss: 0.0754 - val_accuracy: 0.0319
# Epoch 2/30
# 159/159 [==============================] - 62s 389ms/step - loss: 0.0720 - accuracy: 0.0556 - val_loss: 0.0702 - val_accuracy: 0.0652
# Epoch 3/30
# 159/159 [==============================] - 107s 676ms/step - loss: 0.0663 - accuracy: 0.1212 - val_loss: 0.0652 - val_accuracy: 0.1043
# Epoch 4/30
# 159/159 [==============================] - 39s 247ms/step - loss: 0.0609 - accuracy: 0.1904 - val_loss: 0.0616 - val_accuracy: 0.1768
# Epoch 5/30
# 159/159 [==============================] - 43s 267ms/step - loss: 0.0560 - accuracy: 0.2626 - val_loss: 0.0581 - val_accuracy: 0.2188
# Epoch 6/30
# 159/159 [==============================] - 40s 250ms/step - loss: 0.0509 - accuracy: 0.3446 - val_loss: 0.0572 - val_accuracy: 0.2536
# Epoch 7/30
# 159/159 [==============================] - 39s 248ms/step - loss: 0.0454 - accuracy: 0.4234 - val_loss: 0.0536 - val_accuracy: 0.3130
# Epoch 8/30
# 159/159 [==============================] - 41s 259ms/step - loss: 0.0404 - accuracy: 0.4977 - val_loss: 0.0513 - val_accuracy: 0.3420
# Epoch 9/30
# 159/159 [==============================] - 38s 238ms/step - loss: 0.0352 - accuracy: 0.5819 - val_loss: 0.0510 - val_accuracy: 0.3594
# Epoch 10/30
# 159/159 [==============================] - 39s 244ms/step - loss: 0.0300 - accuracy: 0.6637 - val_loss: 0.0549 - val_accuracy: 0.3696
# Epoch 11/30
# 159/159 [==============================] - 42s 264ms/step - loss: 0.0241 - accuracy: 0.7508 - val_loss: 0.0575 - val_accuracy: 0.3348
# Epoch 12/30
# 159/159 [==============================] - 45s 280ms/step - loss: 0.0194 - accuracy: 0.8185 - val_loss: 0.0611 - val_accuracy: 0.3551
# Epoch 13/30
# 159/159 [==============================] - 40s 252ms/step - loss: 0.0152 - accuracy: 0.8774 - val_loss: 0.0677 - val_accuracy: 0.3681
# Epoch 14/30
# 159/159 [==============================] - 39s 241ms/step - loss: 0.0118 - accuracy: 0.9211 - val_loss: 0.0732 - val_accuracy: 0.3420
# Epoch 15/30
# 159/159 [==============================] - 43s 270ms/step - loss: 0.0085 - accuracy: 0.9513 - val_loss: 0.0765 - val_accuracy: 0.3971
# Epoch 16/30
# 159/159 [==============================] - 43s 261ms/step - loss: 0.0064 - accuracy: 0.9747 - val_loss: 0.0831 - val_accuracy: 0.3855
# Epoch 17/30
# 159/159 [==============================] - 41s 256ms/step - loss: 0.0047 - accuracy: 0.9841 - val_loss: 0.0924 - val_accuracy: 0.3696
# Epoch 18/30
# 159/159 [==============================] - 40s 254ms/step - loss: 0.0035 - accuracy: 0.9932 - val_loss: 0.1003 - val_accuracy: 0.3609
# Epoch 19/30
# 159/159 [==============================] - 40s 251ms/step - loss: 0.0039 - accuracy: 0.9880 - val_loss: 0.1031 - val_accuracy: 0.3739
# Epoch 20/30
# 159/159 [==============================] - 47s 291ms/step - loss: 0.0041 - accuracy: 0.9907 - val_loss: 0.1072 - val_accuracy: 0.3696
# Epoch 21/30
# 159/159 [==============================] - 40s 252ms/step - loss: 0.0033 - accuracy: 0.9940 - val_loss: 0.1138 - val_accuracy: 0.3797
# Epoch 22/30
# 159/159 [==============================] - 43s 270ms/step - loss: 0.0025 - accuracy: 0.9972 - val_loss: 0.1147 - val_accuracy: 0.3942
# Epoch 23/30
# 159/159 [==============================] - 41s 256ms/step - loss: 0.0020 - accuracy: 0.9979 - val_loss: 0.1239 - val_accuracy: 0.3928
# Epoch 24/30
# 159/159 [==============================] - 42s 266ms/step - loss: 0.0020 - accuracy: 0.9965 - val_loss: 0.1294 - val_accuracy: 0.3971
# Epoch 25/30
# 159/159 [==============================] - 41s 258ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.1270 - val_accuracy: 0.3725
# Epoch 26/30
# 159/159 [==============================] - 39s 245ms/step - loss: 0.0015 - accuracy: 0.9984 - val_loss: 0.1367 - val_accuracy: 0.3797
# Epoch 27/30
# 159/159 [==============================] - 41s 259ms/step - loss: 0.0026 - accuracy: 0.9957 - val_loss: 0.1297 - val_accuracy: 0.3652
# Epoch 28/30
# 159/159 [==============================] - 41s 257ms/step - loss: 0.0030 - accuracy: 0.9948 - val_loss: 0.1302 - val_accuracy: 0.3754
# Epoch 29/30
# 159/159 [==============================] - 314s 2s/step - loss: 0.0028 - accuracy: 0.9937 - val_loss: 0.1354 - val_accuracy: 0.3536
# Epoch 30/30
# 159/159 [==============================] - 92s 578ms/step - loss: 0.0029 - accuracy: 0.9941 - val_loss: 0.1433 - val_accuracy: 0.3884

# %%
#https://www.tensorflow.org/tutorials/images/classification

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(Epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
break here

# %%
cnnModel.fit(
    train_genX,
    epochs = Epochs,
)
# Out:
# Epoch 1/30
# 159/159 [==============================] - 37s 201ms/step - loss: 0.1038 - accuracy: 0.0182
# Epoch 2/30
# 159/159 [==============================] - 30s 191ms/step - loss: 0.0755 - accuracy: 0.0198
# Epoch 3/30
# 159/159 [==============================] - 29s 184ms/step - loss: 0.0754 - accuracy: 0.0205
# Epoch 4/30
# 159/159 [==============================] - 30s 190ms/step - loss: 0.0753 - accuracy: 0.0188
# Epoch 5/30
# 159/159 [==============================] - 30s 190ms/step - loss: 0.0744 - accuracy: 0.0257
# Epoch 6/30
# 159/159 [==============================] - 31s 192ms/step - loss: 0.0715 - accuracy: 0.0593
# Epoch 7/30
# 159/159 [==============================] - 31s 195ms/step - loss: 0.0691 - accuracy: 0.0839
# Epoch 8/30
# 159/159 [==============================] - 46s 291ms/step - loss: 0.0672 - accuracy: 0.1077
# Epoch 9/30
# 159/159 [==============================] - 32s 204ms/step - loss: 0.0655 - accuracy: 0.1294
# Epoch 10/30
# 159/159 [==============================] - 31s 194ms/step - loss: 0.0633 - accuracy: 0.1574
# Epoch 11/30
# 159/159 [==============================] - 30s 185ms/step - loss: 0.0616 - accuracy: 0.1821
# Epoch 12/30
# 159/159 [==============================] - 30s 187ms/step - loss: 0.0594 - accuracy: 0.2107
# Epoch 13/30
# 159/159 [==============================] - 30s 191ms/step - loss: 0.0572 - accuracy: 0.2436
# Epoch 14/30
# 159/159 [==============================] - 30s 187ms/step - loss: 0.0542 - accuracy: 0.2861
# Epoch 15/30
# 159/159 [==============================] - 30s 187ms/step - loss: 0.0514 - accuracy: 0.3246
# Epoch 16/30
# 159/159 [==============================] - 30s 186ms/step - loss: 0.0482 - accuracy: 0.3783
# Epoch 17/30
# 159/159 [==============================] - 29s 183ms/step - loss: 0.0447 - accuracy: 0.4304
# Epoch 18/30
# 159/159 [==============================] - 29s 184ms/step - loss: 0.0412 - accuracy: 0.4921
# Epoch 19/30
# 159/159 [==============================] - 30s 190ms/step - loss: 0.0369 - accuracy: 0.5604
# Epoch 20/30
# 159/159 [==============================] - 30s 188ms/step - loss: 0.0327 - accuracy: 0.6258
# Epoch 21/30
# 159/159 [==============================] - 30s 187ms/step - loss: 0.0286 - accuracy: 0.6899
# Epoch 22/30
# 159/159 [==============================] - 30s 186ms/step - loss: 0.0241 - accuracy: 0.7594
# Epoch 23/30
# 159/159 [==============================] - 29s 185ms/step - loss: 0.0200 - accuracy: 0.8117
# Epoch 24/30
# 159/159 [==============================] - 34s 214ms/step - loss: 0.0162 - accuracy: 0.8677
# Epoch 25/30
# 159/159 [==============================] - 29s 183ms/step - loss: 0.0130 - accuracy: 0.9088
# Epoch 26/30
# 159/159 [==============================] - 30s 188ms/step - loss: 0.0098 - accuracy: 0.9422
# Epoch 27/30
# 159/159 [==============================] - 30s 188ms/step - loss: 0.0071 - accuracy: 0.9650
# Epoch 28/30
# 159/159 [==============================] - 37s 234ms/step - loss: 0.0053 - accuracy: 0.9833
# Epoch 29/30
# 159/159 [==============================] - 31s 195ms/step - loss: 0.0041 - accuracy: 0.9878
# Epoch 30/30
# 159/159 [==============================] - 30s 186ms/step - loss: 0.0027 - accuracy: 0.9951

# %% [markdown]
# *currently I have no idea how it performs, and I don't think that 0.99 is accurate :)*

# %% [markdown]
# **Break**

# %%
Should Crash and Stop

# %%
test_Gen = ImageDataGenerator(rescale = 1. / 255)
test_genX = train_Gen.flow_from_directory(
    'test',
    target_size = (224, 224),
    batch_size = bSize,
    classes = Classes,
    class_mode = 'categorical'
)
# Out:
# Found 700 images belonging to 70 classes.

# %%
cnnModel.fit(
    test_genX,
    epochs = 5
)
# Out:
# 14/14 [==============================] - 37s 2s/step - loss: 0.2437 - accuracy: 0.0214

# %%
yhat_test = cnnModel.evaluate(test_genX)
# Out:
# 14/14 [==============================] - 6s 388ms/step - loss: 0.1391 - accuracy: 0.2514

# %%
cnnModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 224, 224, 64)      4864
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 74, 74, 128)       204928
#
#  max_pooling2d_1 (MaxPooling  (None, 24, 24, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 70)                9030
#
# =================================================================
# Total params: 9,656,134
# Trainable params: 9,656,134
# Non-trainable params: 0
# _________________________________________________________________

# %%
yhat_test = [ 1 if y>=0.5 else 0 for y in yhat_test ]
yhat_test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# g:\My Drive\UCD\UCD Year 3 Fall\ECS 171\ML.Project.ecs171-main\ML.Project.ecs171-main\dog breeds.ipynb Cell 33 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/g%3A/My%20Drive/UCD/UCD%20Year%203%20Fall/ECS%20171/ML.Project.ecs171-main/ML.Project.ecs171-main/dog%20breeds.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> yhat_test = [ 1 if y>=0.5 else 0 for y in yhat_test ]
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/UCD/UCD%20Year%203%20Fall/ECS%20171/ML.Project.ecs171-main/ML.Project.ecs171-main/dog%20breeds.ipynb#X60sZmlsZQ%3D%3D?line=1'>2</a> yhat_test
#
# g:\My Drive\UCD\UCD Year 3 Fall\ECS 171\ML.Project.ecs171-main\ML.Project.ecs171-main\dog breeds.ipynb Cell 33 in <listcomp>(.0)
# ----> <a href='vscode-notebook-cell:/g%3A/My%20Drive/UCD/UCD%20Year%203%20Fall/ECS%20171/ML.Project.ecs171-main/ML.Project.ecs171-main/dog%20breeds.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> yhat_test = [ 1 if y>=0.5 else 0 for y in yhat_test ]
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/UCD/UCD%20Year%203%20Fall/ECS%20171/ML.Project.ecs171-main/ML.Project.ecs171-main/dog%20breeds.ipynb#X60sZmlsZQ%3D%3D?line=1'>2</a> yhat_test
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# **Save / Load Trained Model**

# %%
# Reference
# https://www.tensorflow.org/tutorials/keras/save_and_load
cnnModel.save_weights('./trained_model/model')

# %%
cnnModel.save('./saved_model/model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./saved_model/model\assets
# INFO:tensorflow:Assets written to: ./saved_model/model\assets

# %%
# Loda model
cnnModel.load_weights('./trained_model/model')

# %%
# Load test data
test =  pd.read_csv('dogs.csv')
test = test[test.dataset == 'test']
test.shape
# Out:
# (700, 3)

# %%
# Preprocess your test the way you did test

# %%
# evaluate your model here
cnnModel.evaluate(test, testlabels) # correct me using example

# %%
vImg = tf.keras.preprocessing.image.load_img("valid/Basenji/10.jpg")
display(vImg)
mybreed = 'Basenji'
# vImg should be formatted in the same way as your train

cnnModel.predict(vImg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# g:\My Drive\UCD\UCD Year 3 Fall\ECS 171\ML.Project.ecs171-main\ML.Project.ecs171-main\dog breeds.ipynb Cell 37 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/g%3A/My%20Drive/UCD/UCD%20Year%203%20Fall/ECS%20171/ML.Project.ecs171-main/ML.Project.ecs171-main/dog%20breeds.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> cnnModel.predict(vImg)
#
# File c:\Users\ZY\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\ZY\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:1083, in select_data_adapter(x, y)
#    1080 adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#    1081 if not adapter_cls:
#    1082     # TODO(scottzhu): This should be a less implementation-specific error.
# -> 1083     raise ValueError(
#    1084         "Failed to find data adapter that can handle "
#    1085         "input: {}, {}".format(_type_name(x), _type_name(y))
#    1086     )
#    1087 elif len(adapter_cls) > 1:
#    1088     raise RuntimeError(
#    1089         "Data adapters should be mutually exclusive for "
#    1090         "handling inputs. Found multiple adapters {} to handle "
#    1091         "input: {}, {}".format(adapter_cls, _type_name(x), _type_name(y))
#    1092     )
#
# ValueError: Failed to find data adapter that can handle input: <class 'PIL.JpegImagePlugin.JpegImageFile'>, <class 'NoneType'>

# %%
test_loss, test_acc = cnnModel.evaluate(test_images,  test_labels, verbose=2)
